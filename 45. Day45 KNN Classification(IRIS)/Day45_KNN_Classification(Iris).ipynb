# %% [markdown]
# <a href="https://colab.research.google.com/github/bayremsyoud/Gestion-de-projets/blob/master/45.%20Day45%20KNN%20Classification(IRIS)/Day45_KNN_Classification(Iris).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                       Day45: KNN Classification (Iris)  By: Loga Aswin

# %%
#importing libraries
import numpy as np
import pandas as pd

# %% [markdown]
# **Data Pre-processing :**

# %%
# Importing the dataset
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df['species'] = df['species'].replace({'Iris-setosa':1, 'Iris-versicolor':2, 'Iris-virginica':3})

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df=df.merge(pd.get_dummies(df.species, prefix='species'), left_index=True, right_index=True)
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_setosa_x  species_versicolor_x  species_virginica_x  \
# 145             False                 False                 True
# 146             False                 False                 True
# 147             False                 False                 True
# 148             False                 False                 True
# 149             False                 False                 True
#
#      species_setosa_y  species_versicolor_y  species_virginica_y  \
# 145             False                 False                 True
# ...

# %%
df.merge(right=df, how='left', left_on='species', right_on='species')
# Out:
#       sepal_length_x  sepal_width_x  petal_length_x  petal_width_x    species  \
# 0                5.1            3.5             1.4            0.2     setosa
# 1                5.1            3.5             1.4            0.2     setosa
# 2                5.1            3.5             1.4            0.2     setosa
# 3                5.1            3.5             1.4            0.2     setosa
# 4                5.1            3.5             1.4            0.2     setosa
# ...              ...            ...             ...            ...        ...
# 7495             5.9            3.0             5.1            1.8  virginica
# 7496             5.9            3.0             5.1            1.8  virginica
# 7497             5.9            3.0             5.1            1.8  virginica
# 7498             5.9            3.0             5.1            1.8  virginica
# 7499             5.9            3.0             5.1            1.8  virginica
#
# ...

# %%
X = df.drop('species', axis=1)
Y = df['species']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 40)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Creating and Training KNN Model:**

# %%
knn_clf = KNeighborsClassifier(n_neighbors=5, metric='euclidean', p=2)
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %% [markdown]
# **Predict Test Results:**

# %%
y_pred = knn_clf.predict(X_test)

# %%
pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
# Out:
#          Actual   Predicted
# 38       setosa      setosa
# 66   versicolor  versicolor
# 115   virginica   virginica
# 117   virginica   virginica
# 89   versicolor  versicolor
# 136   virginica   virginica
# 68   versicolor  versicolor
# 94   versicolor  versicolor
# 84   versicolor  versicolor
# 28       setosa      setosa
# 90   versicolor  versicolor
# 11       setosa      setosa
# 40       setosa      setosa
# 126   virginica   virginica
# 79   versicolor  versicolor
# 144   virginica   virginica
# 123   virginica   virginica
# 124   virginica   virginica
# 76   versicolor  versicolor
# 59   versicolor  versicolor
# 132   virginica   virginica
# 105   virginica   virginica
# 53   versicolor  versicolor
# 17       setosa      setosa
# 64   versicolor  versicolor
# 18       setosa      setosa
# 13       setosa      setosa
# 116   virginica   virginica
# 9        setosa      setosa
# 81   versicolor  versicolor

# %% [markdown]
# **Model Evaluation Metrics**

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

score = accuracy_score(y_test, y_pred)
print(score)
# Out:
# 1.0

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       1.00      1.00      1.00        12
#    virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
m1 = confusion_matrix(y_test, y_pred)
print(m1)
# Out:
# [[ 8  0  0]
#  [ 0 12  0]
#  [ 0  0 10]]
